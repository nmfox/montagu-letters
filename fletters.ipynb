# %%
import nltk
import matplotlib
# %matplotlib inline

# %%
f = open('/Users/administrator/Desktop/DH_ENG/female.txt')
fletters = f.read()

# %%
print(fletters[:30])
# Out:
# i flatter, myself, dear sister

# %%
fletters.count("woman")
# Out:
# 36

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
stops = stopwords.words('english')

# %%
fletters_tokens = word_tokenize(fletters)

# %%
fletters_stops = []
for t in fletters_tokens:
    if t not in stops:
        fletters_stops.append(t)

# %%
print(fletters_stops[:30])
# Out:
# ['flatter', ',', ',', 'dear', 'sister', ',', 'shall', 'give', 'pleasure', 'letting', 'know', 'safely', 'passed', 'sea', ',', 'though', 'ill', 'fortune', 'storm', '.', 'persuaded', 'captain', 'yacht', 'set', 'calm', ',', 'pretended', 'nothing', 'easy', 'tide']

# %%
from nltk.stem import WordNetLemmatizer

# %%
wordnet_lemmatizer = WordNetLemmatizer()

# %%
fletters_clean = [wordnet_lemmatizer.lemmatize(t) for t in fletters_stops]

# %%
print(len(fletters_clean))
print(len(set(fletters_clean)))
# Out:
# 26221
# 4615

# %%
print(fletters_clean)
# Out:
# ['flatter', ',', ',', 'dear', 'sister', ',', 'shall', 'give', 'pleasure', 'letting', 'know', 'safely', 'passed', 'sea', ',', 'though', 'ill', 'fortune', 'storm', '.', 'persuaded', 'captain', 'yacht', 'set', 'calm', ',', 'pretended', 'nothing', 'easy', 'tide', ';', ',', 'two', 'day', 'slowly', 'moving', ',', 'wind', 'blew', 'hard', ',', 'none', 'sailor', 'could', 'keep', 'foot', ',', 'sunday', 'night', 'tossed', 'handsomely', '.', 'never', 'saw', 'man', 'frighted', '(', 'sic', ')', 'captain', '.', 'part', ',', 'lucky', ',', 'neither', 'suffer', 'fear', 'seasickness', ';', 'though', ',', 'confess', ',', 'impatient', 'see', 'upon', 'dry', 'land', ',', 'would', 'stay', 'till', 'yacht', 'could', 'get', 'rotterdam', ',', 'went', 'long-boat', 'helvoetsluys', ',', 'voitures', 'carry', 'u', 'briel', '.', 'charmed', 'neatness', 'little', 'town', ';', 'arrival', 'rotterdam', 'presented', 'new', 'scene', 'pleasure', '.', 'street', 'paved', 'broad', 'stone', ',', 'many', 'meanest', 'artificer', '
# ...
